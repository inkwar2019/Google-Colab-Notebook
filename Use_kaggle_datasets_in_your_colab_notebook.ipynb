# %% [markdown]
# <a href="https://colab.research.google.com/github/inkwar2019/Google-Colab-Notebook/blob/main/Use_kaggle_datasets_in_your_colab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install Kaggle in your Colab Platform

# %%
# !pip install kaggle

# %% [markdown]
# ## In your kaggle Account
# ![Account.PNG](data:image/png;base64,...)
#
# Look a little bit below
# ![api.PNG](data:image/png;base64,...)
# Download kaggle API kaggle.json by clicking the indicating button and upload it during the execution of below code segment.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-92de0e5a-e717-4835-a4a8-d56aa5a72208" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92de0e5a-e717-4835-a4a8-d56aa5a72208">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"sozibhossain","key":"58127459018b5e8894a687a5bfde4932"}'}

# %% [markdown]
# ## Place the kaggle.json file in the correct diretory.

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle
#change perm,ission
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ## Now you can download any kaggle dataset. To download any kaggle dataset you have to copy API command from this perticular dataset.
# ![apiCommand.PNG](data:image/png;base64,...)
#
# Now paste the api command followed by !
#
# !api_command

# %%
# !kaggle datasets download -d vishalsubbiah/pokemon-images-and-types
# Out:
# ...
#   0% 0.00/2.47M [00:00<?, ?B/s]
# 100% 2.47M/2.47M [00:00<00:00, 81.6MB/s]

# %% [markdown]
# ## Now extract the dataset

# %%
from zipfile import ZipFile
file_name = "pokemon-images-and-types.zip"
with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %% [markdown]
# ## Now Look at the dataset
# The dataset is placed in your colab directory.
# ![dataset.PNG](data:image/png;base64,...)

# %%
import pandas as pd

# %%
pokemon = pd.read_csv("pokemon.csv")
pokemon.head()
# Out:
#          Name  Type1   Type2
# 0   bulbasaur  Grass  Poison
# 1     ivysaur  Grass  Poison
# 2    venusaur  Grass  Poison
# 3  charmander   Fire     NaN
# 4  charmeleon   Fire     NaN
